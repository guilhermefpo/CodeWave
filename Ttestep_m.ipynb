# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermeoliveirad/CodeWave/blob/escolas/Ttestep_m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sidrapy
# Out:
# Requirement already satisfied: sidrapy in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from sidrapy) (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from sidrapy) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->sidrapy) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->sidrapy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->sidrapy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->sidrapy) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->sidrapy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->sidrapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->sidrapy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->sidrapy) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->sidrapy) (1.17.0)

# %%
import sidrapy
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/CodeWave/microdados_ed_basica_2022.csv",

                 sep=";", on_bad_lines = 'skip', encoding='Latin 1')
filtro=df[(df['SG_UF']=='SP') &(df['NO_MUNICIPIO']=='São José dos Campos')]

colunas = list(filtro.columns)


bairros_por_regiao = {
    "CENTRO": [
        "CENTRO",
        "JARDIM BELA VISTA",
        "VILA MARIA",
        "VILA NOVA GUARANI",
        "BANHADO",
        "JARDIM PAULISTA",
        "CONJUNTO RESIDENCIAL MONTE CASTELO",
        "JARDIM JUSSARA",
        "VILA SAO PEDRO",
        "JARDIM AUGUSTA",
        "JARDIM OSWALDO CRUZ",
        "VILA ADYANA",
        "JARDIM SAO DIMAS",
        "VILA RUBI",
        "VILA BETANIA",
        "JARDIM RENATA",
        "JARDIM MARINGA",
        "JARDIM ESPLANADA",
        "RESIDENCIAL ESPLANADA DO SOL",
        "JARDIM APOLO",
        "VILA EMA"
    ],

    "LESTE": [
        "VISTA LINDA",
        "VILA INDUSTRIAL",
        "JARDIM ISMENIA",
        "VILA DO TESOURO",
        "JARDIM VALPARAIBA",
        "VILA TATETUBA",
        "BANHADO LESTE",
        "SAPE",
        "JARDIM DAS FLORES",
        "EUGENIO DE MELLO",
        "JARDIM ITAPUA",
        "GALO BRANCO",
        "BANHADO EUGENIO DE MELO",
        "CAMPOS DE SAO JOSE",
        "JARDIM MARIANA",
        "POUSADA DO VALE",
        "PETROBRAS",
        "JARDIM DIAMANTE",
        "JARDIM MOTORAMA",
        "CIDADE VISTA VERDE",
        "VILLAGIO ANTONINI",
        "JARDIM SANTA INES 1",
        "JARDIM SANTA INES 3",
        "FREI GALVAO",
        "JARDIM SAO JOSE",
        "JARDIM PARAISO DO SOL",
        "JARDIM CASTANHEIRA",
        "CHACARAS ARAUJO",
        "JARDIM NOVA MICHIGAN",
        "PARQUE NOVO HORIZONTE",
        "JARDIM SANTA HELENA",
        "RESIDENCIAL DOM BOSCO",
        "PARQUE NOVA ESPERANCA",
        "CAO GROSSO",
        "JARDIM SANTA MARIA",
        "SANTA LUCIA",
        "MAJESTIC",
        "BOM RETIRO",
        "SANTA HERMINIA",
        "CHACARA BOA ESPERANCA",
        "JARDIM SANTA CECILIA",
        "SERROTE",
        "JARDIM HELENA",
        "JARDIM SAO VICENTE",
        "JARDIM NOVA DETROIT",
        "JARDIM PARARANGABA",
        "JARDIM SANTA INES 2",
        "PARQUE TECNOLOGICO",
        "JARDIM NOVA FLORIDA",
        "RESIDENCIAL ANA MARIA",
        "JARDIM AMERICANO"
    ],

    "NORTE": [
        "VILA PAIVA",
        "ALTOS DA VILA PAIVA",
        "VILA SAO GERALDO",
        "ALTO DA PONTE",
        "JARDIM GUIMARAES",
        "JARDIM MINAS GERAIS",
        "VILA DIRCE",
        "JARDIM TELESPARK",
        "ALTOS DE SANTANA",
        "CONDOMINIO JAGUARI",
        "VILA BERFARES",
        "JAGUARI",
        "VILA MACHADO",
        "VILA ALEXANDRINA",
        "SANTANA",
        "VILA CRISTINA",
        "VILA CESAR",
        "VILA ROSSI",
        "VILA RHODIA",
        "BANHADO SANTANA",
        "VARGEM GRANDE",
        "BANHADO VARGEM GRANDE",
        "BUQUIRINHA"
    ],

    "OESTE": [
        "JARDIM DAS INDUSTRIAS",
        "JARDIM ALVORADA",
        "LIMOEIRO",
        "BANHADO OESTE",
        "URBANOVA",
        "BEIRA RIO",
        "JARDIM DO GOLFE",
        "JARDIM COLINAS",
        "BOSQUE IMPERIAL",
        "RESERVA DA BARRA",
        "PARQUE RESIDENCIAL AQUARIUS"
    ],

    "SAO FRANCISCO XAVIER": [
        "SAO FRANCISCO XAVIER"
    ],

    "SUDESTE": [
        "JARDIM SOUTO",
        "IFSP",
        "JARDIM DA GRANJA",
        "JARDIM UIRA",
        "RESIDENCIAL SAO FRANCISCO",
        "PARQUE RESIDENCIAL FLAMBOYANT",
        "SITIO BOM JESUS",
        "DCTA",
        "SETVILLE ALTOS DE SAO JOSE",
        "MIRANTE CAMBUI",
        "JARDIM AEROPORTO",
        "JARDIM SANTA CECILIA 2",
        "JARDIM SANTA JULIA",
        "JARDIM SANTA ROSA",
        "JARDIM DO LAGO",
        "CONJUNTO TOM JOBIM",
        "PINHEIRINHO DOS PALMARES",
        "RESIDENCIAL JATOBA",
        "JARDIM SANTO ONOFRE",
        "JARDIM SAO JUDAS TADEU",
        "CONJUNTO HABITACIONAL SAO JUDAS (POLICIA MILITAR)",
        "VILA ADRIANA",
        "RECANTO DOS NOBRES"
    ],

    "SUL": [
        "JARDIM TORRAO DE OURO",
        "PARQUE INTERLAGOS",
        "JARDIM COLONIAL",
        "CONJUNTO HABITACIONAL ELMANO FERREIRA VELOSO",
        "CONJUNTO HABITACIONAL DOM PEDRO I",
        "JARDIM CRUZEIRO DO SUL",
        "VILA DAS FLORES",
        "JARDIM REPUBLICA",
        "PARQUE DO CERRADO",
        "JARDIM IMPERIAL",
        "CAMPO DOS ALEMAES",
        "CONJUNTO HABITACIONAL DOM PEDRO II",
        "CONJUNTO PAPA JOAO PAULO II",
        "PARQUE DOS IPES",
        "CONDOMINIO COLONIA PARAISO",
        "ESTRADA DO IMPERADOR",
        "JARDIM PORTUGAL",
        "JARDIM ESTORIL",
        "CONDOMINIO PRIMAVERA",
        "BOSQUE DOS EUCALIPTOS",
        "QUINTA DAS FLORES",
        "FLORADAS DE SAO JOSE",
        "JARDIM SATELITE",
        "CIDADE MORUMBI",
        "JARDIM PARAISO",
        "JARDIM ORIENTE",
        "JARDIM SUL",
        "BOSQUE DOS IPES",
        "RESIDENCIAL GAZZO",
        "PARQUE RESIDENCIAL UNIAO",
        "JARDIM AMERICA",
        "JARDIM ANHEMBI",
        "RESIDENCIAL DE VILLE",
        "CONJUNTO HABITACIONAL TRINTA E UM DE MARCO",
        "PARQUE INDUSTRIAL",
        "JARDIM VALE DO SOL",
        "CENTRO INDUSTRIAL ELDORADO",
        "CHACARAS REUNIDAS",
        "MENINO JESUS",
        "RIO COMPRIDO",
        "PALMEIRAS DE SAO JOSE",
        "VILA NAIR",
        "VILA SAO BENTO"
    ]
}




filtro_centro=filtro[filtro['NO_BAIRRO'].isin(bairros_por_regiao['CENTRO'])]
filtro_centro.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
bairros_quant=filtro_centro['BAIRRO'].value_counts().reset_index()
bairros_quant.collumns=['BAIRRO','ESCOLAS']
bairros_quant
# Out:
# /tmp/ipython-input-440724708.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/CodeWave/microdados_ed_basica_2022.csv",
# /tmp/ipython-input-440724708.py:209: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro_centro.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
# /tmp/ipython-input-440724708.py:211: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   bairros_quant.collumns=['BAIRRO','ESCOLAS']
#                  BAIRRO  count
# 0                CENTRO     17
# 1      JARDIM ESPLANADA     14
# 2      JARDIM SAO DIMAS     10
# 3           VILA ADYANA      5
# 4            VILA MARIA      4
# 5              VILA EMA      4
# 6          VILA BETANIA      3
# 7       JARDIM PAULISTA      2
# 8   JARDIM OSWALDO CRUZ      2
# 9        VILA SAO PEDRO      1
# 10            VILA RUBI      1

# %%
filtro_leste=filtro[filtro['NO_BAIRRO'].isin(bairros_por_regiao['LESTE'])]
filtro_leste.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
bairros_quantlest=filtro_leste['BAIRRO'].value_counts().reset_index()
bairros_quantlest.collumns=['BAIRRO','ESCOLAS']
bairros_quantlest
# Out:
# /tmp/ipython-input-4084882132.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro_leste.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
# /tmp/ipython-input-4084882132.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   bairros_quantlest.collumns=['BAIRRO','ESCOLAS']
#                    BAIRRO  count
# 0         VILA INDUSTRIAL     11
# 1        EUGENIO DE MELLO      7
# 2   PARQUE NOVO HORIZONTE      6
# 3           VILA TATETUBA      5
# 4      CAMPOS DE SAO JOSE      5
# 5          JARDIM ISMENIA      4
# 6      CIDADE VISTA VERDE      4
# 7       JARDIM VALPARAIBA      3
# 8        JARDIM AMERICANO      3
# 9         JARDIM MOTORAMA      2
# 10  JARDIM PARAISO DO SOL      2
# 11      JARDIM DAS FLORES      2
# 12     JARDIM CASTANHEIRA      2
# 13     JARDIM SAO VICENTE      2
# 14  PARQUE NOVA ESPERANCA      1
# 15     JARDIM PARARANGABA      1
# 16        JARDIM DIAMANTE      1
# 17   JARDIM NOVA MICHIGAN      1
# 18    JARDIM NOVA DETROIT      1
# 19             BOM RETIRO      1

# %%
filtro_oeste=filtro[filtro['NO_BAIRRO'].isin(bairros_por_regiao['OESTE'])]
filtro_oeste.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
bairros_quantoest=filtro_oeste['BAIRRO'].value_counts().reset_index()
bairros_quantoest.collumns=['BAIRRO','ESCOLAS']
bairros_quantoest
# Out:
# /tmp/ipython-input-901438631.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro_oeste.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
# /tmp/ipython-input-901438631.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   bairros_quantoest.collumns=['BAIRRO','ESCOLAS']
#                         BAIRRO  count
# 0        JARDIM DAS INDUSTRIAS     17
# 1                     URBANOVA      8
# 2  PARQUE RESIDENCIAL AQUARIUS      2
# 3              JARDIM ALVORADA      1

# %%
filtro_norte=filtro[filtro['NO_BAIRRO'].isin(bairros_por_regiao['NORTE'])]
filtro_norte.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
bairros_quantnort=filtro_norte['BAIRRO'].value_counts().reset_index()
bairros_quantnort.collumns=['BAIRRO','ESCOLAS']
bairros_quantnort
# Out:
# /tmp/ipython-input-3275935015.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro_norte.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
# /tmp/ipython-input-3275935015.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   bairros_quantnort.collumns=['BAIRRO','ESCOLAS']
#                 BAIRRO  count
# 0              SANTANA     10
# 1        ALTO DA PONTE      7
# 2     VILA SAO GERALDO      3
# 3     JARDIM TELESPARK      3
# 4           VILA PAIVA      2
# 5     VILA ALEXANDRINA      2
# 6           BUQUIRINHA      2
# 7  ALTOS DA VILA PAIVA      1

# %%
filtro_sul=filtro[filtro['NO_BAIRRO'].isin(bairros_por_regiao['SUL'])]
filtro_sul.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
bairros_quantsul=filtro_sul['BAIRRO'].value_counts().reset_index()
bairros_quantsul.collumns=['BAIRRO','ESCOLAS']
bairros_quantsul
# Out:
# /tmp/ipython-input-886252249.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro_sul.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
# /tmp/ipython-input-886252249.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   bairros_quantsul.collumns=['BAIRRO','ESCOLAS']
#                          BAIRRO  count
# 0               JARDIM SATELITE     23
# 1         BOSQUE DOS EUCALIPTOS     19
# 2                CIDADE MORUMBI     12
# 3             CAMPO DOS ALEMAES     11
# 4             PARQUE INDUSTRIAL     10
# 5                JARDIM ORIENTE      9
# 6                JARDIM AMERICA      7
# 7               JARDIM IMPERIAL      3
# 8          FLORADAS DE SAO JOSE      3
# 9             PARQUE INTERLAGOS      3
# 10             JARDIM REPUBLICA      2
# 11        JARDIM TORRAO DE OURO      2
# 12                 RIO COMPRIDO      2
# 13            CHACARAS REUNIDAS      2
# 14           JARDIM VALE DO SOL      2
# 15              JARDIM PORTUGAL      2
# 16               VILA SAO BENTO      2
# 17               JARDIM ANHEMBI      2
# 18               JARDIM PARAISO      1
# 19                   JARDIM SUL      1
# 20                    VILA NAIR      1
# 21  CONJUNTO PAPA JOAO PAULO II      1
# 22              JARDIM COLONIAL      1
# 23               JARDIM ESTORIL      1
# 24       JARDIM CRUZEIRO DO SUL      1
# 25            RESIDENCIAL GAZZO      1

# %%
filtro_sud=filtro[filtro['NO_BAIRRO'].isin(bairros_por_regiao['SUDESTE'])]
filtro_sud.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
bairros_quantsud=filtro_sud['BAIRRO'].value_counts().reset_index()
bairros_quantsud.collumns=['BAIRRO','ESCOLAS']
bairros_quantsud
# Out:
# /tmp/ipython-input-3878163479.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro_sud.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
# /tmp/ipython-input-3878163479.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   bairros_quantsud.collumns=['BAIRRO','ESCOLAS']
#                           BAIRRO  count
# 0               JARDIM DA GRANJA      4
# 1         JARDIM SAO JUDAS TADEU      4
# 2                    JARDIM UIRA      3
# 3     SETVILLE ALTOS DE SAO JOSE      2
# 4                   JARDIM SOUTO      1
# 5               JARDIM AEROPORTO      1
# 6            JARDIM SANTO ONOFRE      1
# 7             RESIDENCIAL JATOBA      1
# 8  PARQUE RESIDENCIAL FLAMBOYANT      1

# %%
filtro_XAVI=filtro[filtro['NO_BAIRRO'].isin(bairros_por_regiao['SAO FRANCISCO XAVIER'])]
filtro_XAVI.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
bairros_quantXAVI=filtro_XAVI['BAIRRO'].value_counts().reset_index()
bairros_quantXAVI.collumns=['BAIRRO','ESCOLAS']
bairros_quantXAVI
# Out:
# /tmp/ipython-input-3551461362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro_XAVI.rename(columns={'NO_MUNICIPIO': 'MUNICIPIO', 'NO_BAIRRO': 'BAIRRO'}, inplace=True)
# /tmp/ipython-input-3551461362.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   bairros_quantXAVI.collumns=['BAIRRO','ESCOLAS']
#                  BAIRRO  count
# 0  SAO FRANCISCO XAVIER      1
